# %%
# Varför detta ger oss proportionerna 60-20-20 beror på att vi först delar upp data i 80% träning och 20% test, 
# och sedan delar vi den återstående träningen i 75% träning och 25% validering. Så av den ursprungliga datan får vi 60% träning, 
# 20% validering och 20% test.
